# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
visa_df=pd.read_csv('Visadataset - Visadataset.csv')
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
plt.boxplot(visa_df['prevailing_wage'],vert=False)
plt.show()

# %% [markdown]
# # OUTLAYER ANALYSIS

# %% [markdown]
# # STEP-1

# %%
Q1=np.percentile(visa_df['prevailing_wage'],25)
Q2=np.percentile(visa_df['prevailing_wage'],50)
Q3=np.percentile(visa_df['prevailing_wage'],75)
print(Q1)
print(Q2)
print(Q3)
# Out:
# 34015.479999999996
# 70308.20999999999
# 107735.51250000001

# %% [markdown]
# # STEP-2

# %%
IQR=Q3-Q1
print(IQR)
# Out:
# 73720.03250000002

# %%
104945.2275-34015.479999999996
# Out:
# 70929.7475

# %%
#34015.479999999996-104945.2275

# %% [markdown]
# # STEP-3

# %%
lb=Q1-1.5*IQR
print(lb)
# Out:
# -76564.56875000002

# %%
#34015.479999999996-1.5*70929.7475

# %%
ub=Q3+1.5*IQR
print(ub)
# Out:
# 218315.56125000003

# %%
104945.2275+1.5*70929.7475
# Out:
# 211339.84875

# %% [markdown]
# # STEP-4

# %%
c1=visa_df['prevailing_wage']<lb

# %%
c2=visa_df['prevailing_wage']>ub

# %% [markdown]
# **HERE Y WE ARE GIVING | (or) symbol because we have only outlayers at so we use | elase we can use & symbol**

# %%
cm=c1 | c2
outlayers=visa_df[cm]
outlayers
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 14        EZYV15           Asia              Master's                  Y
# 34        EZYV35           Asia              Master's                  N
# 130      EZYV131  South America           High School                  N
# 216      EZYV217           Asia              Master's                  Y
# 221      EZYV222  North America             Doctorate                  Y
# ...          ...            ...                   ...                ...
# 25191  EZYV25192           Asia              Master's                  N
# 25195  EZYV25196  North America              Master's                  Y
# 25468  EZYV25469           Asia            Bachelor's                  N
# 25469  EZYV25470  North America              Master's                  Y
# 25476  EZYV25477           Asia           High School                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %% [markdown]
# # STEP-5

# %%
c1=visa_df['prevailing_wage']>lb

# %%
c2=visa_df['prevailing_wage']<ub

# %%
column1=c1&c2

# %%
nonoutlayers=visa_df[column1]

# %%
nonoutlayers
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25474  EZYV25475    Africa             Doctorate                  N
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
25480-427==25053
# Out:
# True

# %% [markdown]
# # DRAW HISTOGRAM FOR orginaldata and non outlayers data

# %%
plt.hist(visa_df['prevailing_wage'])
plt.hist(nonoutlayers['prevailing_wage'])
plt.show()

# %% [markdown]
# - BOX PLOT FOR ORININAL DATA AND NON-OUTLAYERS DATA

# %%
plt.boxplot(visa_df['prevailing_wage'])
plt.boxplot(nonoutlayers['prevailing_wage'])
plt.show()

# %% [markdown]
# # LETS DRAW HISTOGRAM AND BOXPLOT FOR EACH ONE BY SUBPLOT

# %%
plt.figure(figsize=(9,6))
plt.subplot(2,2,1)
plt.hist(visa_df['prevailing_wage'])
plt.subplot(2,2,2)
plt.boxplot(visa_df['prevailing_wage'])
plt.subplot(2,2,3)
plt.hist(nonoutlayers['prevailing_wage'])
plt.subplot(2,2,4)
plt.boxplot(nonoutlayers['prevailing_wage'])
plt.show()

# %% [markdown]
# - CAN BE ALSO DRAW LIKE THIS
# - TO DECREASE THE LINES

# %%
plt.figure(figsize=(12,8))
plt.subplot(2,2,1).hist(visa_df['prevailing_wage'])
plt.subplot(2,2,2).boxplot(visa_df['prevailing_wage'])
plt.subplot(2,2,3).hist(nonoutlayers['prevailing_wage'])
plt.subplot(2,2,4).boxplot(nonoutlayers['prevailing_wage'])
plt.show()

# %% [markdown]
# # HOW TO DEAL THE OUTLAYERS

# %% [markdown]
# - DROPING OUTLAYERS
#    - WE CAN DIRECTLY DROP THE OUTLAYERS IF OUTLAYERS ARE <2%
#    - GENERALLY WE DO NOT USED THIS BECASUE WE MAY LOSS THE DATA
# - FILLING WITH MEDIAN
#    - AS WE KNOW THAT MEDIAN DOES NOT EFFECTED BY OUTLAYERS
#    - SO ITS IS A GOOD PRACTIC TO DO SO
# - CAPPING WITH Q1 & Q3 VALUES
#   - IF OUTLAYERS PRESENT LOWER BOUNDARY FILL IT WITH Q1 VALUES
#   - IF OUTLAYERS PRESENT UPPER BOUNDARY FILL IT WITH Q3 VALUES

# %%
400/25400*100
# Out:
# 1.574803149606299

# %% [markdown]
# # 07-03-2024
# # FILLING MEDIAN VALUES
# - BY FOR LOOP

# %%
li=[1,2,3,4,32,1,3,4,2,3]
value=10
app=[]
for x in li:
    if x<2 or x>8:
        app.append(value)
    else:
        app.append(x)
app
# Out:
# [10, 2, 3, 4, 10, 10, 3, 4, 2, 3]

# %%
lb=-76564.56875000002
ub=218315.56125000003
med=visa_df['prevailing_wage'].median()
print(med)
emp=[]
for x in visa_df['prevailing_wage']:
    if x<lb or x>ub:
        emp.append(med)
    else:
        emp.append(x)
emp
# Out:
# 70308.20999999999
# [592.2029,
#  83425.65,
#  122996.86,
#  83434.03,
#  149907.39,
#  78252.14,
#  53635.39,
#  418.2298,
#  74362.19,
#  67514.76,
#  83588.56,
#  70813.09,
#  28663.05,
#  107196.03,
#  70308.20999999999,
#  74108.02,
#  3706.79,
#  16132.61,
#  150441.13,
#  79948.12,
#  71128.98,
#  137694.98,
#  45642.39,
#  90108.38,
#  71286.04,
#  99489.65,
#  86332.95,
#  103029.33,
#  40925.86,
#  189190.48,
#  79594.12,
#  135866.13,
#  72077.57,
#  81921.18,
#  70308.20999999999,
#  92421.92,
#  2490.12,
#  110817.26,
#  50960.01,
#  125336.9,
#  39633.32,
#  156326.33,
#  43630.58,
#  54614.42,
#  28989.87,
#  22924.91,
#  61567.75,
#  156251.17,
#  86022.02,
#  49565.37,
#  66191.41,
#  95623.2,
#  115014.05,
#  35018.04,
#  230.8072,
#  113799.64,
#  85854.09,
#  14174.04,
#  47176.84,
#  4949.28,
#  67410.59,
#  58791.58,
#  103.2216,
#  62591.57,
#  102919.59,
#  123468.56,
#  82324.64,
#  5319.49,
#  153019.94,
#  38059.89,
#  230.327,
#  61521.92,
#  121316.5,
# ...

# %% [markdown]
# - SAME DO FOR prevailing_wage DATA
# - ADDING MEDIAN VALUES FOR THE OUTLAYERS

# %%
# NOW ADD THIS TO MAIN DATAFRAME THAT IS VISA_DF['pvage']=pervage
# or new one visa_df['per_new']=pervage
visa_df['prevailing_wage']=emp

# %% [markdown]
# - (or) new column

# %%
visa_df['prevailing_wage_updated']=emp

# %%
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# # NOW LETS DO BOXPLOT

# %%
plt.boxplot(visa_df['prevailing_wage_updated'])
plt.show()
# out layers are gone0

# %% [markdown]
# # NOW WITH OUT FOR LOOP WE CAN REPLACE THE MEDIAN VALUES THAT IS BY USING A METHOD .....

# %% [markdown]
# - read the data again

# %% [markdown]
#     METHOD==np.where()

# %% [markdown]
# - In pervious we have used the normal method to replace the outlayers with median values
# - for ,if, list,Etccccccccccccc...............

# %% [markdown]
# - now we can achive by using np.where

# %% [markdown]
# - create a simple dataframe

# %%
import pandas as pd
import numpy as np

# %%
d={'name':['raghusai','sai','pavan','thaal'],'age':[20,30,21,32]}

# %%
df=pd.DataFrame(d)
df
# Out:
#        name  age
# 0  raghusai   20
# 1       sai   30
# 2     pavan   21
# 3     thaal   32

# %% [markdown]
# - where method it takes 3 things
# - 1 condation
#   - con=df['age']>20
# - 2 true value
#   - 18
# - 3 false value
#   - df['age']

# %%
con=df['age']>20
value=100
otherwise=df['age']

# %%
op=np.where(con,value,otherwise)

# %%
df['age']=op
df
# Out:
#        name  age
# 0  raghusai   20
# 1       sai   18
# 2     pavan   18
# 3     thaal   18

# %% [markdown]
# - DO THE SAME FOR REPLACING MEDIAN VALUES

# %%
lb=-76564.56875000002
ub=218315.56125000003

# %%
md=visa_df['prevailing_wage'].median()
o1=visa_df['prevailing_wage']<lb
o2=visa_df['prevailing_wage']>ub
con=o1 | o2
t=md
f=visa_df['prevailing_wage']

# %%
visa_df['prevailing_wage_new']=np.where(con,t,f)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
# NOW LETS PLOT BOXPLOT TO CHECK outlayes present or not
import matplotlib.pyplot as plt

# %%
plt.boxplot(visa_df['prevailing_wage_new'])
plt.show()
